# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
data = "UCI_Credit_Card.csv"
df=pd.read_csv(data)
df
# Out:
#           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
np.size(df)
# Out:
# 750000

# %%
df.shape
# Out:
# (30000, 25)

# %%
df.info
# Out:
# <bound method DataFrame.info of           ID  LIMIT_BAL  SEX  EDUCATION  MARRIAGE  AGE  PAY_0  PAY_2  PAY_3  \
# 0          1    20000.0    2          2         1   24      2      2     -1
# 1          2   120000.0    2          2         2   26     -1      2      0
# 2          3    90000.0    2          2         2   34      0      0      0
# 3          4    50000.0    2          2         1   37      0      0      0
# 4          5    50000.0    1          2         1   57     -1      0     -1
# ...      ...        ...  ...        ...       ...  ...    ...    ...    ...
# 29995  29996   220000.0    1          3         1   39      0      0      0
# 29996  29997   150000.0    1          3         2   43     -1     -1     -1
# 29997  29998    30000.0    1          2         2   37      4      3      2
# 29998  29999    80000.0    1          3         1   41      1     -1      0
# 29999  30000    50000.0    1          2         1   46      0      0      0
#
# ...

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
x=df["ID"]
y=df["LIMIT_BAL"]
plt.title("ID VS LIMIT_BAL")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["LIMIT_BAL"]
plt.title("ID VS LIMIT_BAL")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["LIMIT_BAL"]
plt.title("ID VS LIMIT_BAL")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_0"]
plt.title("ID VS PAY_0")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_0"]
plt.title("ID VS PAY_0")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_0"]
plt.title("ID VS PAY_0")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_2"]
plt.title("ID VS PAY_2")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_2"]
plt.title("ID VS PAY_2")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_2"]
plt.title("ID VS PAY_2")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_3"]
plt.title("ID VS PAY_3")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_3"]
plt.title("ID VS PAY_3")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_3"]
plt.title("ID VS PAY_3")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_4"]
plt.title("ID VS PAY_4")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_4"]
plt.title("ID VS PAY_4")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_4"]
plt.title("ID VS PAY_4")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_5"]
plt.title("ID VS PAY_5")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_5"]
plt.title("ID VS PAY_5")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_5"]
plt.title("ID VS PAY_5")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_6"]
plt.title("ID VS PAY_6")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_6"]
plt.title("ID VS PAY_6")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_6"]
plt.title("ID VS PAY_6")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT1"]
plt.title("ID VS BILL_AMT1")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT1"]
plt.title("ID VS BILL_AMT1")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT1"]
plt.title("ID VS BILL_AMT1")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT2"]
plt.title("ID VS BILL_AMT2")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT2"]
plt.title("ID VS BILL_AMT2")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT2"]
plt.title("ID VS BILL_AMT2")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT3"]
plt.title("ID VS BILL_AMT3")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT3"]
plt.title("ID VS BILL_AMT3")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT3"]
plt.title("ID VS BILL_AMT3")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT4"]
plt.title("ID VS BILL_AMT4")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT4"]
plt.title("ID VS BILL_AMT4")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT4"]
plt.title("ID VS BILL_AMT4")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT5"]
plt.title("ID VS BILL_AMT5")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT5"]
plt.title("ID VS BILL_AMT5")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT5"]
plt.title("ID VS BILL_AMT5")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT6"]
plt.title("ID VS BILL_AMT6")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT6"]
plt.title("ID VS BILL_AMT6")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["BILL_AMT6"]
plt.title("ID VS BILL_AMT6")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT1"]
plt.title("ID VS PAY_AMT1")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT1"]
plt.title("ID VS PAY_AMT1")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT2"]
plt.title("ID VS PAY_AMT2")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT2"]
plt.title("ID VS PAY_AMT2")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT2"]
plt.title("ID VS PAY_AMT2")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT3"]
plt.title("ID VS PAY_AMT3")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT3"]
plt.title("ID VS PAY_AMT3")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT3"]
plt.title("ID VS PAY_AMT3")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT4"]
plt.title("ID VS PAY_AMT4")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT4"]
plt.title("ID VS PAY_AMT4")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT4"]
plt.title("ID VS PAY_AMT4")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT5"]
plt.title("ID VS PAY_AMT5")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT5"]
plt.title("ID VS PAY_AMT5")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT5"]
plt.title("ID VS PAY_AMT5")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT6"]
plt.title("ID VS PAY_AMT6")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT6"]
plt.title("ID VS PAY_AMT6")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["PAY_AMT6"]
plt.title("ID VS PAY_AMT6")
plt.scatter(x,y)
plt.show()

# %%
x=df["ID"]
y=df["default.payment.next.month"]
plt.title("ID VS default.payment.next.month")
plt.plot(x,y)
plt.show()

# %%
x=df["ID"]
y=df["default.payment.next.month"]
plt.title("ID VS default.payment.next.month")
plt.bar(x,y)
plt.show()

# %%
x=df["ID"]
y=df["default.payment.next.month"]
plt.title("ID VS default.payment.next.month")
plt.scatter(x,y)
plt.show()

# %%
x=df["LIMIT_BAL"]
y=df["SEX"]
plt.title("LIMIT_BAL VS SEX")
plt.plot(x,y)
plt.show()

# %%
x=df["LIMIT_BAL"]
y=df["SEX"]
plt.title("LIMIT_BAL VS SEX")
plt.bar(x,y)
plt.show()

# %%
x=df["LIMIT_BAL"]
y=df["SEX"]
plt.title("LIMIT_BAL VS SEX")
plt.scatter(x,y)
plt.show()

# %%
x=df["AGE"]
y=df["LIMIT_BAL"]
plt.title("AGE VS LIMIT_BAL")
plt.plot(x,y)
plt.show()

# %%
x=df["AGE"]
y=df["LIMIT_BAL"]
plt.title("AGE VS LIMIT_BAL")
plt.bar(x,y)
plt.show()

# %%
x=df["AGE"]
y=df["LIMIT_BAL"]
plt.title("AGE VS LIMIT_BAL")
plt.scatter(x,y)
plt.show()

# %%
df.isna().sum()
# Out:
# ID                            0
# LIMIT_BAL                     0
# SEX                           0
# EDUCATION                     0
# MARRIAGE                      0
# AGE                           0
# PAY_0                         0
# PAY_2                         0
# PAY_3                         0
# PAY_4                         0
# PAY_5                         0
# PAY_6                         0
# BILL_AMT1                     0
# BILL_AMT2                     0
# BILL_AMT3                     0
# BILL_AMT4                     0
# BILL_AMT5                     0
# BILL_AMT6                     0
# PAY_AMT1                      0
# PAY_AMT2                      0
# PAY_AMT3                      0
# PAY_AMT4                      0
# PAY_AMT5                      0
# PAY_AMT6                      0
# default.payment.next.month    0
# dtype: int64

# %%
import missingno as msno

# %%
msno.matrix(df)
# Out:
# <Axes: >
